# %% [markdown]
# # Suhyun Hwang

# %% [markdown]
# # Homework 6

# %% [markdown]
# # Friday Sep 24, 2021

# %%
import numpy as np

# %% [markdown]
# #### Problem 1

# %%
print( 'Problem 1' )
# Out:
# Problem 1

# %% [markdown]
# #### Problem 2

# %%
print( 'Problem 2' )
# Out:
# Problem 2

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 100.1, 0.5)

# %%
print( x )
# Out:
# [  1.    1.5   2.    2.5   3.    3.5   4.    4.5   5.    5.5   6.    6.5
#    7.    7.5   8.    8.5   9.    9.5  10.   10.5  11.   11.5  12.   12.5
#   13.   13.5  14.   14.5  15.   15.5  16.   16.5  17.   17.5  18.   18.5
#   19.   19.5  20.   20.5  21.   21.5  22.   22.5  23.   23.5  24.   24.5
#   25.   25.5  26.   26.5  27.   27.5  28.   28.5  29.   29.5  30.   30.5
#   31.   31.5  32.   32.5  33.   33.5  34.   34.5  35.   35.5  36.   36.5
#   37.   37.5  38.   38.5  39.   39.5  40.   40.5  41.   41.5  42.   42.5
#   43.   43.5  44.   44.5  45.   45.5  46.   46.5  47.   47.5  48.   48.5
#   49.   49.5  50.   50.5  51.   51.5  52.   52.5  53.   53.5  54.   54.5
#   55.   55.5  56.   56.5  57.   57.5  58.   58.5  59.   59.5  60.   60.5
#   61.   61.5  62.   62.5  63.   63.5  64.   64.5  65.   65.5  66.   66.5
#   67.   67.5  68.   68.5  69.   69.5  70.   70.5  71.   71.5  72.   72.5
#   73.   73.5  74.   74.5  75.   75.5  76.   76.5  77.   77.5  78.   78.5
# ...

# %%
y = np.log10( x )

# %%
z = np.sqrt( x )

# %%
plt.plot( y, z )

# %%
plt.figure( figsize = ( 15, 15 ))
plt.plot( x, y, color = 'pink' , linestyle = '--', linewidth = 4, label = 'sin' )
plt.plot( x, z, color = 'purple' , linestyle = '-.', linewidth = 3, label = 'cos')

plt.xlabel( 't'                 , fontsize = 30 )
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 30 )
plt.title( ' My first sin-cos plot' , fontsize = 40 )

plt.gcf().savefig('My first sin-cos plot.pdf') 

plt.show((x, y) and (y, z))

# %%
plt.figure( figsize = ( 15, 15 ))
plt.plot( x, y, color = 'pink' , linestyle = '--', linewidth = 4, label = 'sin' )
plt.plot( x, z, color = 'purple' , linestyle = '-.', linewidth = 3, label = 'cos')

plt.xlabel( 't'                 , fontsize = 30 )
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 30 )
plt.title( ' My first sin-cos plot' , fontsize = 40 )

plt.xlim( 10, 11 )

#change this a bit, so that we see the legend later on:
plt.yticks( np.arange( -1.2, 1.4, step = 0.2 ) ,fontsize=30 ) 
plt.xticks( np.arange( 10, 11.1, 0.2 ) ,fontsize=30 )


plt.tick_params(axis='both',which='major',length=12, width=4,direction='in')

#add the legend so that we see the labels
plt.legend( fontsize = 30 )
plt.show ( x, y, z )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-01c1331e8014> in <module>
#      18 #add the legend so that we see the labels
#      19 plt.legend( fontsize = 30 )
# ---> 20 plt.show ( x, y, z )
#
# ~\miniconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# TypeError: show() takes from 0 to 2 positional arguments but 3 were given

# %%
plt.plot( y, color = 'pink', linestyle = '--', linewidth = 2 )
plt.plot( z, color = 'purple', linestyle = '-', linewidth = 4 )
plt.figure( figsize = ( 15,15 ) )
plt.yticks( fontsize = 20 )
plt.xticks( fontsize = 30 )
plt.show( y, z )
# Out:
#   File "<ipython-input-14-773b861a458d>", line 4
#     plt.y(x)ticks( fontsize = 20 )
#                 ^
# SyntaxError: invalid syntax

# %%
plt.plot( y, z )
plt.plot( y, color = 'pink', linestyle = '--', linewidth = 2 )
plt.plot( z, color = 'purple', linestyle = '-', linewidth = 4 )
plt.figure( figsize = ( 15,15 ) )
plt.yticks( fontsize = 20 )
plt.xticks( fontsize = 30 )
plt.title( 'My first plot' )
plt.show( y, z )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-996e53caa742> in <module>
#       6 plt.xticks( fontsize = 30 )
#       7 plt.title( 'My first plot' )
# ----> 8 plt.show( y, z )
#
# ~\miniconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# ~\miniconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.plot( y, color = 'pink', linestyle = '--', linewidth = 2 )
plt.plot( z, color = 'purple', linestyle = '-', linewidth = 4 )

# %%
plt.titles( 'Function for HW6', fontsize = 44 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-57604e0e3279> in <module>
# ----> 1 plt.titles( 'Function for HW6', fontsize = 44 )
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'titles'

# %%
plt.savefig( 'Function for HW6', format = 'pdf' )

#plt.savefig( 'my_first_saved_figure.pdf', format = 'pdf', 
#            dpi = 1200, bbox_inches = 'tight', pad_inches = 0.3 )

# %%
plt.figure( figsize = ( 15,15 ) )
plt.ythicks( fontsize = 20 )
plt.xthicks( fontsize = 30 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-f0e77c940334> in <module>
#       1 plt.figure( figsize = ( 15,15 ) )
# ----> 2 plt.ythicks( fontsize = 20 )
#       3 plt.xthicks( fontsize = 30 )
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ythicks'

# %% [markdown]
# #### Problem 3

# %%
print( 'Problem 3' )
# Out:
# Problem 3

# %%
q = np.array([ 45, 24, 5, 30, 3, 67, 33, 60, 65, 13, 82, 75, 21, 77, 67, 8, 86, 62, 23, 70, 11, 70, 21, 15, 84, 51, 6, 79, 78, 66, 2, 93, 49, 74, 23, 85, 25, 38, 1, 89 ])

# %%
print( q )
# Out:
# [45 24  5 30  3 67 33 60 65 13 82 75 21 77 67  8 86 62 23 70 11 70 21 15
#  84 51  6 79 78 66  2 93 49 74 23 85 25 38  1 89]

# %%
np.where( q > 50 )
# Out:
# (array([ 5,  7,  8, 10, 11, 13, 14, 16, 17, 19, 21, 24, 25, 27, 28, 29, 31,
#         33, 35, 39], dtype=int64),)

# %%
print( q[(q > 50 ) & (q < 70)] )
# Out:
# [67 60 65 67 62 51 66]

# %%
test_list = z

# %%
print( test_list )
# Out:
# [ 1.          1.22474487  1.41421356  1.58113883  1.73205081  1.87082869
#   5.83095189  5.87367006  5.91607978  5.95818764  6.          6.04152299
#   6.08276253  6.12372436  6.164414    6.20483682  6.244998    6.28490254
# ...

# %% [markdown]
# #### Changing element 21 of test_tuple to 44.0
#
# After running 'test_tuple [21] = 44.0' the element successfully changed We can see above that the 21st of the element is shown as 44.

# %%
word_list = [ 'twinkle', 'twinkle', 'little', 'star' ]

# %%
print ( word_list[ 0 ])
print ( word_list[ 0 ].find('a') )
print ( word_list[ 0 ].find('e') )
# Out:
# twinkle
# -1
# 6

# %%
print ( word_list[ 1 ])
print ( word_list[ 1 ].find('a') )
print ( word_list[ 1 ].find('e') )
# Out:
# twinkle
# -1
# 6

# %%
print ( word_list[ 2 ])
print ( word_list[ 2 ].find('a') )
print ( word_list[ 2 ].find('e') )
# Out:
# little
# -1
# 5

# %%
print ( word_list[ 3 ])
print ( word_list[ 3 ].find('a') )
print ( word_list[ 3 ].find('e') )
# Out:
# star
# 2
# -1

# %%
'e' in word_list[0]
# Out:
# True

# %%
'a' in word_list[0]
# Out:
# False

# %%
'e' in word_list[1]
# Out:
# True

# %%
'a' in word_list[1]
# Out:
# False

# %%
'e' in word_list[2]
# Out:
# True

# %%
'a' in word_list[2]
# Out:
# False

# %%
'e' in word_list[3]
# Out:
# False

# %%
'a' in word_list[3]
# Out:
# True

# %%
print(  word_list[0].index( 'a' ) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-131ba231c891> in <module>
# ----> 1 print(  word_list[0].index( 'a' ) )
#
# ValueError: substring not found

# %%
print(  word_list[0].index( 'e' ) )
# Out:
# 6

# %%
print(  word_list[1].index( 'a' ) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-58d76af609b4> in <module>
# ----> 1 print(  word_list[1].index( 'a' ) )
#
# ValueError: substring not found

# %%
print(  word_list[1].index( 'e' ) )
# Out:
# 6

# %%
print(  word_list[2].index( 'a' ) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-1f808d57d1d8> in <module>
# ----> 1 print(  word_list[2].index( 'a' ) )
#
# ValueError: substring not found

# %%
print(  word_list[2].index( 'e' ) )
# Out:
# 5

# %%
print(  word_list[3].index( 'a' ) )
# Out:
# 2

# %%
print(  word_list[3].index( 'e' ) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-92f5b8f22977> in <module>
# ----> 1 print(  word_list[3].index( 'e' ) )
#
# ValueError: substring not found

# %%
is_this_name_in_list = 'star'

word_list[0] == is_this_name_in_list
word_list[1] == is_this_name_in_list
word_list[2] == is_this_name_in_list
word_list[3] == is_this_name_in_list
# Out:
# True

# %%
is_this_name_in_list = 'bright'

word_list[0] == is_this_name_in_list
word_list[1] == is_this_name_in_list
word_list[2] == is_this_name_in_list
word_list[3] == is_this_name_in_list
# Out:
# False

# %% [markdown]
# #### Problem 4

# %%
print( 'Problem 4' )
# Out:
# Problem 4

# %%
def quad( a ,b ,c ):
    from math import sqrt
    # This is the function to calculate the roots of a quadratic equation.
    f1 = b**2 - 4*a*c
    f2 = sqrt(f1)
    positive = ( -b + f2 ) / ( 2 * a )
    negative = ( -b - f2 ) / ( 2 * a )
    return positive, negative

# %%
roots = quad( 1 ,-1 ,-12 )
print( roots )
# Out:
# (4.0, -3.0)

# %% [markdown]
# #### Problem 5

# %%
print( 'Problem 5 ')
# Out:
# Problem 5
