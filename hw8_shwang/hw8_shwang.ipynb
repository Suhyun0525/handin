# %%
# Making the imports
import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from math import pi

# %%
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# %%
x = np.arange(-100, 100.0, 0.1)
y = np.arange(-100, 100.0, 0.1)

# %%
from math import pi

u = 1
v = 0.5
a = 2.
b = 1.5

t = np.linspace(0, 2*pi, 100)
plt.plot( u+a*np.cos(t), v+b*np.sin(t))
plt.grid(color = 'lightgray', linestyle = '--')
plt.show()

# %%
# Building the model
a = 12
b = 2
X = -100
Y = 0
steps = 2000  # The number of iterations to perform gradient descent

#n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
#y = sqrt((1 - x^2/a^2)*b^2)
for i in range(steps): 
    if (1 - (X*X)/(a*a)) >= 0:
        y[i] = sqrt((1 - (X*X)/(a*a))*(b*b))  # The current predicted value of Y
    X += .1
    
#print ('Epoch %d: ' %epochs, a, b, c, d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-37811cc2dc43> in <module>
#      12 for i in range(steps):
#      13     if (1 - (X*X)/(a*a)) >= 0:
# ---> 14         y[i] = sqrt((1 - (X*X)/(a*a))*(b*b))  # The current predicted value of Y
#      15     X += .1
#      16
#
# TypeError: 'float' object does not support item assignment

# %%
# Making predictions
# plt.scatter(x, y)
plt.scatter(x, y, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-0b28733ae7be> in <module>
#       1 # Making predictions
#       2 # plt.scatter(x, y)
# ----> 3 plt.scatter(x, y, color='red')
#       4 plt.show()
#
# ~\miniconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    3071         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
# -> 3072         **({"data": data} if data is not None else {}), **kwargs)
#    3073     sci(__ret)
#    3074     return __ret
#
# ~\miniconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# ...

# %%
from numpy import *
from matplotlib.pyplot import *

# %%
def ellipse(x, y, a, b):
    """Function that plots an ellipse"""
    equation = ( x**2 / a**2 ) + ( y**2 / b**2 ) - 1

    return equation
    
    # plt.plot()

# %%
a = 12
b = 2
print(ellipse(x, y, a, b))
# Out:
# [2568.44444444 2563.308125   2558.17694444 ... 2553.05090278 2558.17694444
#  2563.308125  ]

# %%
def ellipse(x, y, a, b):
    """Function that plots an ellipse"""
    equation = ( x**2 / a**2 ) + ( y**2 / b**2 ) - 1
    
    plt.plot(equation, color = 'lightgreen')
    plt.show()

    return equation

# %%
a = 12
b = 2
print(ellipse(x, y, a, b))
# Out:
# [2568.44444444 2563.308125   2558.17694444 ... 2553.05090278 2558.17694444
#  2563.308125  ]

# %%
def ellipse(x, y, a, b):
    """Function that plots an ellipse"""
    equation = ( x**2 / a**2 ) + ( y**2 / b**2 ) - 1
    
    
    t = np.linspace(0, 2*pi, 100)
    plt.plot(equation, color = 'lightgreen')
    plt.show()

    return equation

# %%
a = 12
b = 2
print(ellipse(x, y, a, b))
# Out:
# [2568.44444444 2563.308125   2558.17694444 ... 2553.05090278 2558.17694444
#  2563.308125  ]

# %%
def ellipse(x, y, a, b):
    return ( x**2 / a**2 ) + ( y**2 / b**2 ) - 1

# %%
a = 12
b = 2
print(ellipse(x, y, a, b))
# Out:
# [2568.44444444 2563.308125   2558.17694444 ... 2553.05090278 2558.17694444
#  2563.308125  ]

# %%
def ellipse(x, y, a, b):
    """Function that plots an ellipse"""
    
    plt.figure()
    ax = plt.gca()
    
    
    ellipse = Ellipse((0, 0), width = b, height = a, 
                      edgecolor = 'r', fc = 'None', lw=2)
    
    plt.show()
    
    return ax.add_patch(ellipse)

# %%
a = 12
b = 2
print(ellipse(x, y, a, b))
# Out:
# Ellipse(xy=(0, 0), width=2, height=12, angle=0)

# %%
def ellipse(x, y, a, b):
    """Function that plots an ellipse"""
    
    x_position = x
    y_position = y
    x_radius = a
    y_radius = b
    
    t = linspace(0, 360, 360)
    plt.plot( (( x**2 / a**2 ) + ( y**2 / b**2 ) - 1 ))
    plt.grid(color = 'lightgreen', linestyle = '--')
    
    return plt.show()

# %%
a = 12
b = 2
print(ellipse(x, y, a, b))
# Out:
# None

# %%
def ellipse(x, y, a, b):
    """Function that plots an ellipse"""
    
    x,y = np.meshgrid(x,y)
    
    z = (( x**2 / a**2 ) + ( y**2 / b**2 ) - 1 ) ""
    
    fig, ax = plt.subplots()
    
    ax.contour(x,y,z,[0])
   # ax.set_aspect(1)
    plt.xlim(-15,15)
    plt.ylim(-25,25)
    
    return plt.show()

# %%
a = 12
b = 2
print(ellipse(x, y, a, b))
# Out:
# None

# %%
a = 4
b = 20
print(ellipse(x, y, a, b))
# Out:
# None

# %% [markdown]
# #### Problem 3

# %%
print('Problem 3')
# Out:
# Problem 3

# %%
from hw8_support_funct import order_array

# %%
input_array = np.array([4,5,2,10,42,22,8,12])
order_array(input_array)
# Out:
# [ 2  4  5  8 10 12 22 42]

# %%
for i in range(len(list1)):
        m_index = i   
        for j in range(i, len(list1)):    """Find the minimum value among i"""
            if list1[j] <  list1[m_index]:    """In input_array, one loop is i and """
                m_index = j
        list1[i],list1[m_index] = list1[m_index], list1[i]
        
print(list1)
# Out:
#   File "<ipython-input-14-36081ed8071b>", line 4
#     if list1[j] <  list1[m_index]:    """In input_array, one loop is i and """
#     ^
# IndentationError: unexpected indent

# %%
np.sort(np.array([4,5,2,10,42,22,8,12]))
# Out:
# array([ 2,  4,  5,  8, 10, 12, 22, 42])
